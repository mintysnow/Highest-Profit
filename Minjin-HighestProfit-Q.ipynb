# %%
import pandas as pd
import json

# %% [markdown]
# # Part 1

# %%
# Read into memory
df = pd.read_csv("data.csv")
df.head()
# Out:
#    Year  Rank           Company  Revenue (in millions) Profit (in millions)
# 0  1955     1    General Motors                 9823.5                  806
# 1  1955     2       Exxon Mobil                 5661.4                584.8
# 2  1955     3        U.S. Steel                 3250.4                195.4
# 3  1955     4  General Electric                 2959.1                212.6
# 4  1955     5            Esmark                 2510.8                 19.1

# %%
# Print # of rows in the CSV data.
print(df.shape[0])
# Out:
# 25500

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
#Remove all rows with 'profit' that is not numerical value.

df1 = df[pd.to_numeric(df["Profit (in millions)"], errors="coerce").notnull()]

# %%
#Then print out how many rows of data are left, after removing all the rows with 
#invalid non-numeric profit column data
print(df1.shape[0])
# Out:
# 25131

# %% [markdown]
# # Part 2

# %%
json_str = df1.to_json(orient="records")
json_arr = json.loads(json_str)

# %%
# write to file
with open("data2.json", "w") as outfile:
    json.dump(json_str, outfile)

# %%
json_arr
# Out:
# [{'Year': 1955,
#   'Rank': 1,
#   'Company': 'General Motors',
#   'Revenue (in millions)': 9823.5,
#   'Profit (in millions)': '806'},
#  {'Year': 1955,
#   'Rank': 2,
#   'Company': 'Exxon Mobil',
#   'Revenue (in millions)': 5661.4,
#   'Profit (in millions)': '584.8'},
#  {'Year': 1955,
#   'Rank': 3,
#   'Company': 'U.S. Steel',
#   'Revenue (in millions)': 3250.4,
#   'Profit (in millions)': '195.4'},
#  {'Year': 1955,
#   'Rank': 4,
#   'Company': 'General Electric',
#   'Revenue (in millions)': 2959.1,
#   'Profit (in millions)': '212.6'},
#  {'Year': 1955,
#   'Rank': 5,
#   'Company': 'Esmark',
#   'Revenue (in millions)': 2510.8,
#   'Profit (in millions)': '19.1'},
#  {'Year': 1955,
#   'Rank': 6,
#   'Company': 'Chrysler',
#   'Revenue (in millions)': 2071.6,
#   'Profit (in millions)': '18.5'},
#  {'Year': 1955,
#   'Rank': 7,
#   'Company': 'Armour',
#   'Revenue (in millions)': 2056.1,
#   'Profit (in millions)': '1.6'},
#  {'Year': 1955,
#   'Rank': 8,
#   'Company': 'Gulf Oil',
#   'Revenue (in millions)': 1705.3,
#   'Profit (in millions)': '182.8'},
#  {'Year': 1955,
#   'Rank': 9,
#   'Company': 'Mobil',
#   'Revenue (in millions)': 1703.6,
#   'Profit (in millions)': '183.8'},
#  {'Year': 1955,
#   'Rank': 10,
#   'Company': 'DuPont',
#   'Revenue (in millions)': 1687.7,
#   'Profit (in millions)': '344.4'},
#  {'Year': 1955,
#   'Rank': 11,
#   'Company': 'Amoco',
#   'Revenue (in millions)': 1667.4,
#   'Profit (in millions)': '132.8'},
#  {'Year': 1955,
#   'Rank': 12,
#   'Company': 'Bethlehem Steel',
#   'Revenue (in millions)': 1660.3,
#   'Profit (in millions)': '117.2'},
#  {'Year': 1955,
#   'Rank': 13,
#   'Company': 'CBS',
#   'Revenue (in millions)': 1631.0,
#   'Profit (in millions)': '84.6'},
#  {'Year': 1955,
#   'Rank': 14,
#   'Company': 'Texaco',
#   'Revenue (in millions)': 1574.4,
#   'Profit (in millions)': '226.1'},
#  {'Year': 1955,
#   'Rank': 15,
#   'Company': 'AT&T Technologies',
#   'Revenue (in millions)': 1526.2,
#   'Profit (in millions)': '55.8'},
#  {'Year': 1955,
#   'Rank': 16,
#   'Company': 'Shell Oil',
#   'Revenue (in millions)': 1312.1,
#   'Profit (in millions)': '121.1'},
#  {'Year': 1955,
#   'Rank': 17,
#   'Company': 'Kraft',
#   'Revenue (in millions)': 1210.3,
#   'Profit (in millions)': '37.4'},
#  {'Year': 1955,
#   'Rank': 18,
#   'Company': 'ChevronTexaco',
#   'Revenue (in millions)': 1113.3,
#   'Profit (in millions)': '211.9'},
#  {'Year': 1955,
#   'Rank': 19,
#   'Company': 'Goodyear Tire & Rubber',
#   'Revenue (in millions)': 1090.1,
#   'Profit (in millions)': '48.1'},
#  {'Year': 1955,
#   'Rank': 20,
#   'Company': 'Boeing',
#   'Revenue (in millions)': 1033.2,
#   'Profit (in millions)': '37'},
#  {'Year': 1955,
#   'Rank': 21,
#   'Company': 'Sinclair Oil',
#   'Revenue (in millions)': 1021.5,
#   'Profit (in millions)': '91.6'},
#  {'Year': 1955,
#   'Rank': 22,
#   'Company': 'Navistar International',
#   'Revenue (in millions)': 994.1,
#   'Profit (in millions)': '36.3'},
#  {'Year': 1955,
#   'Rank': 23,
#   'Company': 'RCA',
#   'Revenue (in millions)': 941.0,
#   'Profit (in millions)': '40.5'},
#  {'Year': 1955,
#   'Rank': 24,
#   'Company': 'Union Carbide',
#   'Revenue (in millions)': 923.7,
#   'Profit (in millions)': '89.8'},
#  {'Year': 1955,
#   'Rank': 25,
#   'Company': 'Firestone Tire & Rubber',
#   'Revenue (in millions)': 916.0,
#   'Profit (in millions)': '40.5'},
#  {'Year': 1955,
#   'Rank': 26,
#   'Company': 'Douglas Aircraft',
#   'Revenue (in millions)': 915.2,
#   'Profit (in millions)': '36.2'},
#  {'Year': 1955,
#   'Rank': 27,
#   'Company': 'Procter & Gamble',
#   'Revenue (in millions)': 911.0,
#   'Profit (in millions)': '52.3'},
#  {'Year': 1955,
#   'Rank': 28,
#   'Company': 'Republic Steel',
#   'Revenue (in millions)': 846.3,
#   'Profit (in millions)': '52.9'},
#  {'Year': 1955,
#   'Rank': 29,
#   'Company': 'Citgo Petroleum',
#   'Revenue (in millions)': 813.2,
#   'Profit (in millions)': '43.7'},
#  {'Year': 1955,
#   'Rank': 30,
#   'Company': 'ConocoPhillips',
#   'Revenue (in millions)': 794.6,
#   'Profit (in millions)': '76.2'},
#  {'Year': 1955,
#   'Rank': 31,
#   'Company': 'General Foods',
#   'Revenue (in millions)': 783.0,
#   'Profit (in millions)': '27.9'},
#  {'Year': 1955,
#   'Rank': 32,
#   'Company': 'Uniroyal',
#   'Revenue (in millions)': 782.6,
#   'Profit (in millions)': '28'},
#  {'Year': 1955,
#   'Rank': 33,
#   'Company': 'Borden Chemical',
#   'Revenue (in millions)': 776.8,
#   'Profit (in millions)': '22.7'},
#  {'Year': 1955,
#   'Rank': 34,
#   'Company': 'Lockheed Martin',
#   'Revenue (in millions)': 732.9,
#   'Profit (in millions)': '22.4'},
#  {'Year': 1955,
#   'Rank': 35,
#   'Company': 'Alcoa',
#   'Revenue (in millions)': 708.3,
#   'Profit (in millions)': '46.5'},
#  {'Year': 1955,
#   'Rank': 36,
#   'Company': 'International Paper',
#   'Revenue (in millions)': 681.2,
#   'Profit (in millions)': '73.5'},
#  {'Year': 1955,
#   'Rank': 37,
#   'Company': 'Wilson',
#   'Revenue (in millions)': 680.5,
#   'Profit (in millions)': '3.1'},
#  {'Year': 1955,
#   'Rank': 38,
#   'Company': 'Sunoco',
#   'Revenue (in millions)': 659.5,
#   'Profit (in millions)': '40.3'},
#  {'Year': 1955,
#   'Rank': 39,
#   'Company': 'United Technologies',
#   'Revenue (in millions)': 654.2,
#   'Profit (in millions)': '26'},
#  {'Year': 1955,
#   'Rank': 40,
#   'Company': 'American Can',
#   'Revenue (in millions)': 652.4,
#   'Profit (in millions)': '30.4'},
#  {'Year': 1955,
#   'Rank': 41,
#   'Company': 'General Dynamics',
#   'Revenue (in millions)': 648.6,
#   'Profit (in millions)': '20.8'},
#  {'Year': 1955,
#   'Rank': 42,
#   'Company': 'Rockwell Automation',
#   'Revenue (in millions)': 645.8,
#   'Profit (in millions)': '22.2'},
#  {'Year': 1955,
#   'Rank': 43,
#   'Company': 'Eastman Kodak',
#   'Revenue (in millions)': 633.5,
#   'Profit (in millions)': '69.8'},
#  {'Year': 1955,
#   'Rank': 44,
#   'Company': 'Goodrich',
#   'Revenue (in millions)': 630.7,
#   'Profit (in millions)': '38.8'},
#  {'Year': 1955,
#   'Rank': 45,
#   'Company': 'Continental Group',
#   'Revenue (in millions)': 616.2,
#   'Profit (in millions)': '20.7'},
#  {'Year': 1955,
#   'Rank': 46,
#   'Company': 'Bendix',
#   'Revenue (in millions)': 607.7,
#   'Profit (in millions)': '25.5'},
#  {'Year': 1955,
#   'Rank': 47,
#   'Company': 'Atlantic Richfield',
#   'Revenue (in millions)': 596.2,
#   'Profit (in millions)': '36.8'},
#  {'Year': 1955,
#   'Rank': 48,
#   'Company': 'Fortune Brands',
#   'Revenue (in millions)': 533.1,
#   'Profit (in millions)': '41.3'},
#  {'Year': 1955,
#   'Rank': 49,
#   'Company': 'Ryerson Tull',
#   'Revenue (in millions)': 532.0,
#   'Profit (in millions)': '41.1'},
#  {'Year': 1955,
#   'Rank': 50,
#   'Company': 'ARMCO',
#   'Revenue (in millions)': 530.8,
#   'Profit (in millions)': '43.1'},
#  {'Year': 1955,
#   'Rank': 51,
#   'Company': 'Honeywell Intl.',
#   'Revenue (in millions)': 519.7,
#   'Profit (in millions)': '10.8'},
#  {'Year': 1955,
#   'Rank': 52,
#   'Company': 'AMAX',
#   'Revenue (in millions)': 509.5,
#   'Profit (in millions)': '43.1'},
#  {'Year': 1955,
#   'Rank': 53,
#   'Company': 'Conoco',
#   'Revenue (in millions)': 500.1,
#   'Profit (in millions)': '41.7'},
#  {'Year': 1955,
#   'Rank': 54,
#   'Company': 'Allis-Chalmers',
#   'Revenue (in millions)': 492.9,
#   'Profit (in millions)': '26.1'},
#  {'Year': 1955,
#   'Rank': 55,
#   'Company': 'Jones & Laughlin Steel',
#   'Revenue (in millions)': 492.9,
#   'Profit (in millions)': '25'},
#  {'Year': 1955,
#   'Rank': 56,
#   'Company': 'General Mills',
#   'Revenue (in millions)': 487.6,
#   'Profit (in millions)': '11.2'},
#  {'Year': 1955,
#   'Rank': 57,
#   'Company': 'National Intergroup',
#   'Revenue (in millions)': 484.1,
#   'Profit (in millions)': '30.3'},
#  {'Year': 1955,
#   'Rank': 58,
#   'Company': 'Curtiss-Wright',
#   'Revenue (in millions)': 475.1,
#   'Profit (in millions)': '19.4'},
#  {'Year': 1955,
#   'Rank': 59,
#   'Company': 'Olin',
#   'Revenue (in millions)': 470.1,
#   'Profit (in millions)': '34.3'},
#  {'Year': 1955,
#   'Rank': 60,
#   'Company': 'Asarco',
#   'Revenue (in millions)': 466.8,
#   'Profit (in millions)': '21.5'},
#  {'Year': 1955,
#   'Rank': 61,
#   'Company': 'Intl. Business Machines',
#   'Revenue (in millions)': 461.4,
#   'Profit (in millions)': '46.5'},
#  {'Year': 1955,
#   'Rank': 62,
#   'Company': 'Anaconda',
#   'Revenue (in millions)': 461.1,
#   'Profit (in millions)': '26.7'},
#  {'Year': 1955,
#   'Rank': 63,
#   'Company': 'Tidewater Oil',
#   'Revenue (in millions)': 459.0,
#   'Profit (in millions)': '34.5'},
#  {'Year': 1955,
#   'Rank': 64,
#   'Company': 'Cudahy',
#   'Revenue (in millions)': 454.8,
#   'Profit (in millions)': '-7.2'},
#  {'Year': 1955,
#   'Rank': 65,
#   'Company': 'Briggs Manufacturing',
#   'Revenue (in millions)': 440.9,
#   'Profit (in millions)': '0.8'},
#  {'Year': 1955,
#   'Rank': 66,
#   'Company': 'Sperry',
#   'Revenue (in millions)': 440.9,
#   'Profit (in millions)': '28.5'},
#  {'Year': 1955,
#   'Rank': 67,
#   'Company': 'Nabisco Group Holdings',
#   'Revenue (in millions)': 438.3,
#   'Profit (in millions)': '44.8'},
#  {'Year': 1955,
#   'Rank': 68,
#   'Company': 'PPG Industries',
#   'Revenue (in millions)': 431.0,
#   'Profit (in millions)': '38.6'},
#  {'Year': 1955,
#   'Rank': 69,
#   'Company': 'Dow Chemical',
#   'Revenue (in millions)': 428.3,
#   'Profit (in millions)': '33.4'},
#  {'Year': 1955,
#   'Rank': 70,
#   'Company': 'Youngstown Sheet & Tube',
#   'Revenue (in millions)': 428.2,
#   'Profit (in millions)': '20.2'},
#  {'Year': 1955,
#   'Rank': 71,
#   'Company': 'Kennecott',
#   'Revenue (in millions)': 423.6,
#   'Profit (in millions)': '77.9'},
#  {'Year': 1955,
#   'Rank': 72,
#   'Company': 'NL Industries',
#   'Revenue (in millions)': 419.3,
#   'Profit (in millions)': '36.6'},
#  {'Year': 1955,
#   'Rank': 73,
#   'Company': 'Standard Brands',
#   'Revenue (in millions)': 415.9,
#   'Profit (in millions)': '10.6'},
#  {'Year': 1955,
#   'Rank': 74,
#   'Company': 'Sealed Air',
#   'Revenue (in millions)': 413.4,
#   'Profit (in millions)': '14.8'},
#  {'Year': 1955,
#   'Rank': 75,
#   'Company': 'Caterpillar',
#   'Revenue (in millions)': 401.0,
#   'Profit (in millions)': '25.1'},
#  {'Year': 1955,
#   'Rank': 76,
#   'Company': 'American Motors',
#   'Revenue (in millions)': 400.3,
#   'Profit (in millions)': '-11.1'},
#  {'Year': 1955,
#   'Rank': 77,
#   'Company': 'Ralston Purina',
#   'Revenue (in millions)': 399.6,
#   'Profit (in millions)': '15.5'},
#  {'Year': 1955,
#   'Rank': 78,
#   'Company': 'American Cyanamid',
#   'Revenue (in millions)': 397.6,
#   'Profit (in millions)': '27.1'},
#  {'Year': 1955,
#   'Rank': 79,
#   'Company': 'Pullman',
#   'Revenue (in millions)': 391.0,
#   'Profit (in millions)': '13.3'},
#  {'Year': 1955,
#   'Rank': 80,
#   'Company': 'Pure Oil',
#   'Revenue (in millions)': 388.3,
#   'Profit (in millions)': '31.2'},
#  {'Year': 1955,
#   'Rank': 81,
#   'Company': 'BorgWarner',
#   'Revenue (in millions)': 380.3,
#   'Profit (in millions)': '24.5'},
#  {'Year': 1955,
#   'Rank': 82,
#   'Company': 'Nabisco Brands',
#   'Revenue (in millions)': 376.4,
#   'Profit (in millions)': '19.9'},
#  {'Year': 1955,
#   'Rank': 83,
#   'Company': 'Avco',
#   'Revenue (in millions)': 375.4,
#   'Profit (in millions)': '3.6'},
#  {'Year': 1955,
#   'Rank': 84,
#   'Company': 'Unocal',
#   'Revenue (in millions)': 349.7,
#   'Profit (in millions)': '35.9'},
#  {'Year': 1955,
#   'Rank': 85,
#   'Company': 'Philco',
#   'Revenue (in millions)': 349.3,
#   'Profit (in millions)': '6.8'},
#  {'Year': 1955,
#   'Rank': 86,
#   'Company': 'Burlington Industries Equity',
#   'Revenue (in millions)': 347.5,
#   'Profit (in millions)': '8.4'},
#  {'Year': 1955,
#   'Rank': 87,
#   'Company': 'Monsanto',
#   'Revenue (in millions)': 341.8,
#   'Profit (in millions)': '23.7'},
#  {'Year': 1955,
#   'Rank': 88,
#   'Company': 'Campbell Soup',
#   'Revenue (in millions)': 338.7,
#   'Profit (in millions)': '23.6'},
#  {'Year': 1955,
#   'Rank': 89,
#   'Company': 'Owens-Illinois',
#   'Revenue (in millions)': 336.7,
#   'Profit (in millions)': '21.5'},
#  {'Year': 1955,
#   'Rank': 90,
#   'Company': 'Pillsbury',
#   'Revenue (in millions)': 336.0,
#   'Profit (in millions)': '4.9'},
#  {'Year': 1955,
#   'Rank': 91,
#   'Company': 'Singer',
#   'Revenue (in millions)': 333.9,
#   'Profit (in millions)': '11.9'},
#  {'Year': 1955,
#   'Rank': 92,
#   'Company': 'Hormel Foods',
#   'Revenue (in millions)': 331.8,
#   'Profit (in millions)': '1.8'},
#  {'Year': 1955,
#   'Rank': 93,
#   'Company': 'Hygrade Food Products',
#   'Revenue (in millions)': 324.2,
#   'Profit (in millions)': '1'},
#  {'Year': 1955,
#   'Rank': 94,
#   'Company': 'Republic Aviation',
#   'Revenue (in millions)': 323.5,
#   'Profit (in millions)': '9'},
#  {'Year': 1955,
#   'Rank': 95,
#   'Company': 'Carnation',
#   'Revenue (in millions)': 310.0,
#   'Profit (in millions)': '7.7'},
#  {'Year': 1955,
#   'Rank': 96,
#   'Company': 'Amstar',
#   'Revenue (in millions)': 308.8,
#   'Profit (in millions)': '7.6'},
#  {'Year': 1955,
#   'Rank': 97,
#   'Company': 'Reynolds Metals',
#   'Revenue (in millions)': 306.8,
#   'Profit (in millions)': '20.3'},
#  {'Year': 1955,
#   'Rank': 98,
#   'Company': 'Morrell (John)',
#   'Revenue (in millions)': 306.5,
#   'Profit (in millions)': '0.5'},
#  {'Year': 1955,
#   'Rank': 99,
#   'Company': 'BP America',
#   'Revenue (in millions)': 304.4,
#   'Profit (in millions)': '18.5'},
#  {'Year': 1955,
#   'Rank': 100,
#   'Company': 'American Standard',
#   'Revenue (in millions)': 303.4,
#   'Profit (in millions)': '20.4'},
#  {'Year': 1955,
#   'Rank': 101,
#   'Company': 'United Merchants & Mfrs.',
#   'Revenue (in millions)': 300.1,
#   'Profit (in millions)': '9.2'},
#  {'Year': 1955,
#   'Rank': 102,
#   'Company': 'Crane',
#   'Revenue (in millions)': 299.8,
#   'Profit (in millions)': '5.8'},
#  {'Year': 1955,
#   'Rank': 103,
#   'Company': 'Crown Zellerbach',
#   'Revenue (in millions)': 298.0,
#   'Profit (in millions)': '26.8'},
#  {'Year': 1955,
#   'Rank': 104,
#   'Company': 'Deere',
#   'Revenue (in millions)': 295.6,
#   'Profit (in millions)': '20.6'},
#  {'Year': 1955,
#   'Rank': 105,
#   'Company': 'Liggett Group',
#   'Revenue (in millions)': 294.1,
#   'Profit (in millions)': '22.2'},
#  {'Year': 1955,
#   'Rank': 106,
#   'Company': 'Sylvania Electric Products',
#   'Revenue (in millions)': 281.6,
#   'Profit (in millions)': '9.5'},
#  {'Year': 1955,
#   'Rank': 107,
#   'Company': 'J.P. Stevens',
#   'Revenue (in millions)': 277.6,
#   'Profit (in millions)': '3.6'},
#  {'Year': 1955,
#   'Rank': 108,
#   'Company': 'Phelps Dodge',
#   'Revenue (in millions)': 277.1,
#   'Profit (in millions)': '41.2'},
#  {'Year': 1955,
#   'Rank': 109,
#   'Company': 'Beatrice',
#   'Revenue (in millions)': 275.0,
#   'Profit (in millions)': '4.8'},
#  {'Year': 1955,
#   'Rank': 110,
#   'Company': 'Rath Packing',
#   'Revenue (in millions)': 273.6,
#   'Profit (in millions)': '1.4'},
#  {'Year': 1955,
#   'Rank': 111,
#   'Company': 'Martin Marietta',
#   'Revenue (in millions)': 270.7,
#   'Profit (in millions)': '20.1'},
#  {'Year': 1955,
#   'Rank': 112,
#   'Company': 'TRW',
#   'Revenue (in millions)': 269.0,
#   'Profit (in millions)': '11.7'},
#  {'Year': 1955,
#   'Rank': 113,
#   'Company': 'Quaker Oats',
#   'Revenue (in millions)': 266.1,
#   'Profit (in millions)': '8.9'},
#  {'Year': 1955,
#   'Rank': 114,
#   'Company': 'Weyerhaeuser',
#   'Revenue (in millions)': 262.5,
#   'Profit (in millions)': '35.5'},
#  {'Year': 1955,
#   'Rank': 115,
#   'Company': 'Colgate-Palmolive',
#   'Revenue (in millions)': 261.8,
#   'Profit (in millions)': '12.5'},
#  {'Year': 1955,
#   'Rank': 116,
#   'Company': 'NCR',
#   'Revenue (in millions)': 259.1,
#   'Profit (in millions)': '12.7'},
#  {'Year': 1955,
#   'Rank': 117,
#   'Company': 'Manville',
#   'Revenue (in millions)': 253.2,
#   'Profit (in millions)': '16.7'},
#  {'Year': 1955,
#   'Rank': 118,
#   'Company': 'Babcock & Wilcox',
#   'Revenue (in millions)': 250.5,
#   'Profit (in millions)': '15.2'},
#  {'Year': 1955,
#   'Rank': 119,
#   'Company': 'CF&I Steel',
#   'Revenue (in millions)': 250.2,
#   'Profit (in millions)': '7.1'},
#  {'Year': 1955,
#   'Rank': 120,
#   'Company': 'A.O. Smith',
#   'Revenue (in millions)': 249.6,
#   'Profit (in millions)': '5.4'},
#  {'Year': 1955,
#   'Rank': 121,
#   'Company': 'Marathon Oil',
#   'Revenue (in millions)': 248.5,
#   'Profit (in millions)': '38.2'},
#  {'Year': 1955,
#   'Rank': 122,
#   'Company': 'Foremost Dairies',
#   'Revenue (in millions)': 247.4,
#   'Profit (in millions)': '6.1'},
#  {'Year': 1955,
#   'Rank': 123,
#   'Company': 'Furniture Brands Intl.',
#   'Revenue (in millions)': 246.8,
#   'Profit (in millions)': '10.2'},
#  {'Year': 1955,
#   'Rank': 124,
#   'Company': 'ACF Industries',
#   'Revenue (in millions)': 245.1,
#   'Profit (in millions)': '7.8'},
#  {'Year': 1955,
#   'Rank': 125,
#   'Company': 'Otis Elevator',
#   'Revenue (in millions)': 244.0,
#   'Profit (in millions)': '6.3'},
#  {'Year': 1955,
#   'Rank': 126,
#   'Company': 'Coca-Cola',
#   'Revenue (in millions)': 243.3,
#   'Profit (in millions)': '25.9'},
#  {'Year': 1955,
#   'Rank': 127,
#   'Company': 'Rockwell-Standard',
#   'Revenue (in millions)': 241.8,
#   'Profit (in millions)': '12.1'},
#  {'Year': 1955,
#   'Rank': 128,
#   'Company': 'J.E. Seagram',
#   'Revenue (in millions)': 236.3,
#   'Profit (in millions)': '25.7'},
#  {'Year': 1955,
#   'Rank': 129,
#   'Company': 'Grumman',
#   'Revenue (in millions)': 235.3,
#   'Profit (in millions)': '11.2'},
#  {'Year': 1955,
#   'Rank': 130,
#   'Company': 'National Supply',
#   'Revenue (in millions)': 231.7,
#   'Profit (in millions)': '9.3'},
#  {'Year': 1955,
#   'Rank': 131,
#   'Company': '3M',
#   'Revenue (in millions)': 230.9,
#   'Profit (in millions)': '24.6'},
#  {'Year': 1955,
#   'Rank': 132,
#   'Company': 'Honeywell',
#   'Revenue (in millions)': 229.4,
#   'Profit (in millions)': '15.3'},
#  {'Year': 1955,
#   'Rank': 133,
#   'Company': 'Scott Paper',
#   'Revenue (in millions)': 228.8,
#   'Profit (in millions)': '18.8'},
#  {'Year': 1955,
#   'Rank': 134,
#   'Company': 'Ashland',
#   'Revenue (in millions)': 227.9,
#   'Profit (in millions)': '6.6'},
#  {'Year': 1955,
#   'Rank': 135,
#   'Company': 'Del Monte Foods',
#   'Revenue (in millions)': 226.9,
#   'Profit (in millions)': '6.7'},
#  {'Year': 1955,
#   'Rank': 136,
#   'Company': 'Kaisertech',
#   'Revenue (in millions)': 226.6,
#   'Profit (in millions)': '14'},
#  {'Year': 1955,
#   'Rank': 137,
#   'Company': 'Remington Rand',
#   'Revenue (in millions)': 225.5,
#   'Profit (in millions)': '12.2'},
#  {'Year': 1955,
#   'Rank': 138,
#   'Company': 'FMC',
#   'Revenue (in millions)': 225.3,
#   'Profit (in millions)': '12.1'},
#  {'Year': 1955,
#   'Rank': 139,
#   'Company': 'Oscar Mayer',
#   'Revenue (in millions)': 224.4,
#   'Profit (in millions)': '2.8'},
#  {'Year': 1955,
#   'Rank': 140,
#   'Company': 'Richfield Oil',
#   'Revenue (in millions)': 222.8,
#   'Profit (in millions)': '25.6'},
#  {'Year': 1955,
#   'Rank': 141,
#   'Company': 'Studebaker',
#   'Revenue (in millions)': 222.3,
#   'Profit (in millions)': '-26.2'},
#  {'Year': 1955,
#   'Rank': 142,
#   'Company': 'H.J. Heinz',
#   'Revenue (in millions)': 220.6,
#   'Profit (in millions)': '5.6'},
#  {'Year': 1955,
#   'Rank': 143,
#   'Company': 'Admiral',
#   'Revenue (in millions)': 219.6,
#   'Profit (in millions)': '6.5'},
#  {'Year': 1955,
#   'Rank': 144,
#   'Company': 'Armstrong Holdings',
#   'Revenue (in millions)': 217.6,
#   'Profit (in millions)': '11.9'},
#  {'Year': 1955,
#   'Rank': 145,
#   'Company': 'American Viscose',
#   'Revenue (in millions)': 217.2,
#   'Profit (in millions)': '10.5'},
#  {'Year': 1955,
#   'Rank': 146,
#   'Company': 'USG',
#   'Revenue (in millions)': 217.0,
#   'Profit (in millions)': '32.4'},
#  {'Year': 1955,
#   'Rank': 147,
#   'Company': 'GenCorp',
#   'Revenue (in millions)': 217.0,
#   'Profit (in millions)': '4.5'},
#  {'Year': 1955,
#   'Rank': 148,
#   'Company': 'Anheuser-Busch',
#   'Revenue (in millions)': 215.9,
#   'Profit (in millions)': '12.8'},
#  {'Year': 1955,
#   'Rank': 149,
#   'Company': 'Libby, McNeill & Libby',
#   'Revenue (in millions)': 215.4,
#   'Profit (in millions)': '4.2'},
#  {'Year': 1955,
#   'Rank': 150,
#   'Company': 'Continental Baking',
#   'Revenue (in millions)': 212.5,
#   'Profit (in millions)': '5.7'},
#  {'Year': 1955,
#   'Rank': 151,
#   'Company': 'Kaiser Industries',
#   'Revenue (in millions)': 212.4,
#   'Profit (in millions)': '-35.5'},
#  {'Year': 1955,
#   'Rank': 152,
#   'Company': 'Aeroquip-Vickers',
#   'Revenue (in millions)': 212.3,
#   'Profit (in millions)': '24'},
#  {'Year': 1955,
#   'Rank': 153,
#   'Company': 'Skelly Oil',
#   'Revenue (in millions)': 211.1,
#   'Profit (in millions)': '29.5'},
#  {'Year': 1955,
#   'Rank': 154,
#   'Company': 'Glidden',
#   'Revenue (in millions)': 209.1,
#   'Profit (in millions)': '7.1'},
#  {'Year': 1955,
#   'Rank': 155,
#   'Company': 'Archer Daniels Midland',
#   'Revenue (in millions)': 207.7,
#   'Profit (in millions)': '5'},
#  {'Year': 1955,
#   'Rank': 156,
#   'Company': 'Motorola',
#   'Revenue (in millions)': 205.2,
#   'Profit (in millions)': '7.6'},
#  {'Year': 1955,
#   'Rank': 157,
#   'Company': 'Wyeth',
#   'Revenue (in millions)': 203.1,
#   'Profit (in millions)': '16.2'},
#  {'Year': 1955,
#   'Rank': 158,
#   'Company': 'International Packers',
#   'Revenue (in millions)': 202.5,
#   'Profit (in millions)': '0.4'},
#  {'Year': 1955,
#   'Rank': 159,
#   'Company': 'Johnson & Johnson',
#   'Revenue (in millions)': 200.9,
#   'Profit (in millions)': '9.5'},
#  {'Year': 1955,
#   'Rank': 160,
#   'Company': 'Quantum Chemical',
#   'Revenue (in millions)': 200.1,
#   'Profit (in millions)': '13.7'},
#  {'Year': 1955,
#   'Rank': 161,
#   'Company': 'St. Regis',
#   'Revenue (in millions)': 200.1,
#   'Profit (in millions)': '14.9'},
#  {'Year': 1955,
#   'Rank': 162,
#   'Company': 'Electric Autolite',
#   'Revenue (in millions)': 198.5,
#   'Profit (in millions)': '0.7'},
#  {'Year': 1955,
#   'Rank': 163,
#   'Company': 'Arden Farms',
#   'Revenue (in millions)': 195.1,
#   'Profit (in millions)': '1.9'},
#  {'Year': 1955,
#   'Rank': 164,
#   'Company': 'Bestfoods',
#   'Revenue (in millions)': 194.7,
#   'Profit (in millions)': '15.8'},
#  {'Year': 1955,
#   'Rank': 165,
#   'Company': 'Revere Copper & Brass',
#   'Revenue (in millions)': 193.3,
#   'Profit (in millions)': '10.3'},
#  {'Year': 1955,
#   'Rank': 166,
#   'Company': 'Hearst Consolidated Publications',
#   'Revenue (in millions)': 190.9,
#   'Profit (in millions)': '-0.3'},
#  {'Year': 1955,
#   'Rank': 167,
#   'Company': 'Wheeling Pittsburgh',
#   'Revenue (in millions)': 187.6,
#   'Profit (in millions)': '9.6'},
#  {'Year': 1955,
#   'Rank': 168,
#   'Company': 'Koppers',
#   'Revenue (in millions)': 187.6,
#   'Profit (in millions)': '6.1'},
#  {'Year': 1955,
#   'Rank': 169,
#   'Company': 'Hercules',
#   'Revenue (in millions)': 187.5,
#   'Profit (in millions)': '14.1'},
#  {'Year': 1955,
#   'Rank': 170,
#   'Company': 'Alco Products',
#   'Revenue (in millions)': 187.2,
#   'Profit (in millions)': '4.6'},
#  {'Year': 1955,
#   'Rank': 171,
#   'Company': 'Container Corp. of America',
#   'Revenue (in millions)': 186.6,
#   'Profit (in millions)': '13.6'},
#  {'Year': 1955,
#   'Rank': 172,
#   'Company': 'M. Lowenstein',
#   'Revenue (in millions)': 186.0,
#   'Profit (in millions)': '6.8'},
#  {'Year': 1955,
#   'Rank': 173,
#   'Company': 'Bell Intercontinental',
#   'Revenue (in millions)': 185.6,
#   'Profit (in millions)': '6.4'},
#  {'Year': 1955,
#   'Rank': 174,
#   'Company': 'Continental Motors',
#   'Revenue (in millions)': 182.1,
#   'Profit (in millions)': '4.5'},
#  {'Year': 1955,
#   'Rank': 175,
#   'Company': 'Cannon Mills',
#   'Revenue (in millions)': 180.2,
#   'Profit (in millions)': '9.1'},
#  {'Year': 1955,
#   'Rank': 176,
#   'Company': 'Pet',
#   'Revenue (in millions)': 178.2,
#   'Profit (in millions)': '8.1'},
#  {'Year': 1955,
#   'Rank': 177,
#   'Company': 'Kimberly-Clark',
#   'Revenue (in millions)': 177.3,
#   'Profit (in millions)': '11.1'},
#  {'Year': 1955,
#   'Rank': 178,
#   'Company': 'Raytheon',
#   'Revenue (in millions)': 177.1,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1955,
#   'Rank': 179,
#   'Company': 'Dart Industries',
#   'Revenue (in millions)': 176.1,
#   'Profit (in millions)': '3.3'},
#  {'Year': 1955,
#   'Rank': 180,
#   'Company': 'Wesson Oil & Snowdrift',
#   'Revenue (in millions)': 175.5,
#   'Profit (in millions)': '6.7'},
#  {'Year': 1955,
#   'Rank': 181,
#   'Company': 'Curtis Publishing',
#   'Revenue (in millions)': 173.4,
#   'Profit (in millions)': '4.5'},
#  {'Year': 1955,
#   'Rank': 182,
#   'Company': 'Schenley Industries',
#   'Revenue (in millions)': 172.0,
#   'Profit (in millions)': '3.8'},
#  {'Year': 1955,
#   'Rank': 183,
#   'Company': 'Northrop Grumman',
#   'Revenue (in millions)': 171.4,
#   'Profit (in millions)': '3.8'},
#  {'Year': 1955,
#   'Rank': 184,
#   'Company': 'Allegheny International',
#   'Revenue (in millions)': 169.6,
#   'Profit (in millions)': '4.2'},
#  {'Year': 1955,
#   'Rank': 185,
#   'Company': 'Whirlpool',
#   'Revenue (in millions)': 169.5,
#   'Profit (in millions)': '9.2'},
#  {'Year': 1955,
#   'Rank': 186,
#   'Company': 'Kellogg',
#   'Revenue (in millions)': 169.5,
#   'Profit (in millions)': '12.7'},
#  {'Year': 1955,
#   'Rank': 187,
#   'Company': 'Unisys',
#   'Revenue (in millions)': 169.1,
#   'Profit (in millions)': '7.8'},
#  {'Year': 1955,
#   'Rank': 188,
#   'Company': 'Walter Industries',
#   'Revenue (in millions)': 167.2,
#   'Profit (in millions)': '2.6'},
#  {'Year': 1955,
#   'Rank': 189,
#   'Company': 'Eaton',
#   'Revenue (in millions)': 165.2,
#   'Profit (in millions)': '8.6'},
#  {'Year': 1955,
#   'Rank': 190,
#   'Company': 'Westvaco',
#   'Revenue (in millions)': 164.8,
#   'Profit (in millions)': '13.1'},
#  {'Year': 1955,
#   'Rank': 191,
#   'Company': 'Sterling Drug',
#   'Revenue (in millions)': 164.3,
#   'Profit (in millions)': '13.1'},
#  {'Year': 1955,
#   'Rank': 192,
#   'Company': 'Mid-Continent Petroleum',
#   'Revenue (in millions)': 164.2,
#   'Profit (in millions)': '13.5'},
#  {'Year': 1955,
#   'Rank': 193,
#   'Company': 'Rheem Manufacturing',
#   'Revenue (in millions)': 163.6,
#   'Profit (in millions)': '6'},
#  {'Year': 1955,
#   'Rank': 194,
#   'Company': 'Gillette',
#   'Revenue (in millions)': 162.2,
#   'Profit (in millions)': '26.1'},
#  {'Year': 1955,
#   'Rank': 195,
#   'Company': 'Crucible Steel',
#   'Revenue (in millions)': 160.6,
#   'Profit (in millions)': '3.7'},
#  {'Year': 1955,
#   'Rank': 196,
#   'Company': "Brink's",
#   'Revenue (in millions)': 159.7,
#   'Profit (in millions)': '2'},
#  {'Year': 1955,
#   'Rank': 197,
#   'Company': 'Hershey Foods',
#   'Revenue (in millions)': 159.4,
#   'Profit (in millions)': '7.1'},
#  {'Year': 1955,
#   'Rank': 198,
#   'Company': 'General American Transportation',
#   'Revenue (in millions)': 156.2,
#   'Profit (in millions)': '11.4'},
#  {'Year': 1955,
#   'Rank': 199,
#   'Company': 'Baldwin-Lima-Hamilton',
#   'Revenue (in millions)': 155.2,
#   'Profit (in millions)': '4.1'},
#  {'Year': 1955,
#   'Rank': 200,
#   'Company': 'Dana',
#   'Revenue (in millions)': 153.5,
#   'Profit (in millions)': '12.3'},
#  {'Year': 1955,
#   'Rank': 201,
#   'Company': 'Central Soya',
#   'Revenue (in millions)': 153.1,
#   'Profit (in millions)': '3.9'},
#  {'Year': 1955,
#   'Rank': 202,
#   'Company': 'Carrier',
#   'Revenue (in millions)': 151.4,
#   'Profit (in millions)': '6.9'},
#  {'Year': 1955,
#   'Rank': 203,
#   'Company': 'Grinnell',
#   'Revenue (in millions)': 150.9,
#   'Profit (in millions)': '8'},
#  {'Year': 1955,
#   'Rank': 204,
#   'Company': 'Combustion Engineering',
#   'Revenue (in millions)': 150.5,
#   'Profit (in millions)': '6.6'},
#  {'Year': 1955,
#   'Rank': 205,
#   'Company': 'Genesco',
#   'Revenue (in millions)': 150.1,
#   'Profit (in millions)': '4.8'},
#  {'Year': 1955,
#   'Rank': 206,
#   'Company': 'Chance Vought',
#   'Revenue (in millions)': 149.6,
#   'Profit (in millions)': '6.6'},
#  {'Year': 1955,
#   'Rank': 207,
#   'Company': 'Newport News Shipbuilding',
#   'Revenue (in millions)': 149.5,
#   'Profit (in millions)': '7.2'},
#  {'Year': 1955,
#   'Rank': 208,
#   'Company': 'Consolidation Coal',
#   'Revenue (in millions)': 149.2,
#   'Profit (in millions)': '12.1'},
#  {'Year': 1955,
#   'Rank': 209,
#   'Company': 'Corning',
#   'Revenue (in millions)': 147.9,
#   'Profit (in millions)': '17.5'},
#  {'Year': 1955,
#   'Rank': 210,
#   'Company': 'Celanese',
#   'Revenue (in millions)': 147.6,
#   'Profit (in millions)': '6.6'},
#  {'Year': 1955,
#   'Rank': 211,
#   'Company': 'Fruehauf',
#   'Revenue (in millions)': 146.3,
#   'Profit (in millions)': '4.5'},
#  {'Year': 1955,
#   'Rank': 212,
#   'Company': 'Merck',
#   'Revenue (in millions)': 145.5,
#   'Profit (in millions)': '12.6'},
#  {'Year': 1955,
#   'Rank': 213,
#   'Company': 'White Motor',
#   'Revenue (in millions)': 145.5,
#   'Profit (in millions)': '4.9'},
#  {'Year': 1955,
#   'Rank': 214,
#   'Company': 'International Cellucotton Products',
#   'Revenue (in millions)': 145.4,
#   'Profit (in millions)': '7.4'},
#  {'Year': 1955,
#   'Rank': 215,
#   'Company': 'Pfizer',
#   'Revenue (in millions)': 145.2,
#   'Profit (in millions)': '15.2'},
#  {'Year': 1955,
#   'Rank': 216,
#   'Company': 'Pabst Brewing',
#   'Revenue (in millions)': 145.0,
#   'Profit (in millions)': '2.1'},
#  {'Year': 1955,
#   'Rank': 217,
#   'Company': 'Staley Continental',
#   'Revenue (in millions)': 144.9,
#   'Profit (in millions)': '5.3'},
#  {'Year': 1955,
#   'Rank': 218,
#   'Company': 'Altria Group',
#   'Revenue (in millions)': 142.8,
#   'Profit (in millions)': '11.4'},
#  {'Year': 1955,
#   'Rank': 219,
#   'Company': 'National Sugar Refining',
#   'Revenue (in millions)': 140.7,
#   'Profit (in millions)': '2.3'},
#  {'Year': 1955,
#   'Rank': 220,
#   'Company': 'Cone Mills',
#   'Revenue (in millions)': 140.7,
#   'Profit (in millions)': '2.6'},
#  {'Year': 1955,
#   'Rank': 221,
#   'Company': 'Fairchild Engine & Airplane',
#   'Revenue (in millions)': 140.4,
#   'Profit (in millions)': '4.1'},
#  {'Year': 1955,
#   'Rank': 222,
#   'Company': 'Simmons',
#   'Revenue (in millions)': 139.1,
#   'Profit (in millions)': '5.4'},
#  {'Year': 1955,
#   'Rank': 223,
#   'Company': 'Brown Shoe',
#   'Revenue (in millions)': 138.9,
#   'Profit (in millions)': '4.8'},
#  {'Year': 1955,
#   'Rank': 224,
#   'Company': 'Zenith Electronics',
#   'Revenue (in millions)': 138.6,
#   'Profit (in millions)': '5.7'},
#  {'Year': 1955,
#   'Rank': 225,
#   'Company': 'Foster Wheeler',
#   'Revenue (in millions)': 138.6,
#   'Profit (in millions)': '3.6'},
#  {'Year': 1955,
#   'Rank': 226,
#   'Company': 'Studebaker-Worthington',
#   'Revenue (in millions)': 138.3,
#   'Profit (in millions)': '6.9'},
#  {'Year': 1955,
#   'Rank': 227,
#   'Company': 'Owens Corning',
#   'Revenue (in millions)': 136.5,
#   'Profit (in millions)': '8.4'},
#  {'Year': 1955,
#   'Rank': 228,
#   'Company': 'Timken',
#   'Revenue (in millions)': 135.6,
#   'Profit (in millions)': '10.7'},
#  {'Year': 1955,
#   'Rank': 230,
#   'Company': 'American Bakeries',
#   'Revenue (in millions)': 134.8,
#   'Profit (in millions)': '4.4'},
#  {'Year': 1955,
#   'Rank': 231,
#   'Company': 'Campbell Taggart',
#   'Revenue (in millions)': 133.9,
#   'Profit (in millions)': '4.3'},
#  {'Year': 1955,
#   'Rank': 232,
#   'Company': 'Endicott Johnson',
#   'Revenue (in millions)': 133.3,
#   'Profit (in millions)': '2.1'},
#  {'Year': 1955,
#   'Rank': 233,
#   'Company': 'McGraw-Edison',
#   'Revenue (in millions)': 132.8,
#   'Profit (in millions)': '9.4'},
#  {'Year': 1955,
#   'Rank': 234,
#   'Company': 'Rohm & Haas',
#   'Revenue (in millions)': 132.6,
#   'Profit (in millions)': '12.4'},
#  {'Year': 1955,
#   'Rank': 235,
#   'Company': 'Lorillard',
#   'Revenue (in millions)': 131.5,
#   'Profit (in millions)': '6.3'},
#  {'Year': 1955,
#   'Rank': 236,
#   'Company': 'Ingersoll-Rand',
#   'Revenue (in millions)': 130.3,
#   'Profit (in millions)': '23'},
#  {'Year': 1955,
#   'Rank': 237,
#   'Company': 'Dresser Industries',
#   'Revenue (in millions)': 130.2,
#   'Profit (in millions)': '7.4'},
#  {'Year': 1955,
#   'Rank': 238,
#   'Company': 'Kaiser Steel',
#   'Revenue (in millions)': 128.5,
#   'Profit (in millions)': '7.9'},
#  {'Year': 1955,
#   'Rank': 239,
#   'Company': 'Cletrac',
#   'Revenue (in millions)': 128.3,
#   'Profit (in millions)': '3.7'},
#  {'Year': 1955,
#   'Rank': 240,
#   'Company': 'Champion Papers',
#   'Revenue (in millions)': 128.0,
#   'Profit (in millions)': '9.5'},
#  {'Year': 1955,
#   'Rank': 241,
#   'Company': 'National Gypsum',
#   'Revenue (in millions)': 126.6,
#   'Profit (in millions)': '13.1'},
#  {'Year': 1955,
#   'Rank': 242,
#   'Company': 'AMF',
#   'Revenue (in millions)': 126.5,
#   'Profit (in millions)': '4'},
#  {'Year': 1955,
#   'Rank': 243,
#   'Company': 'Clinton Foods',
#   'Revenue (in millions)': 125.7,
#   'Profit (in millions)': '3.9'},
#  {'Year': 1955,
#   'Rank': 244,
#   'Company': 'Sunray Oil',
#   'Revenue (in millions)': 125.2,
#   'Profit (in millions)': '23.2'},
#  {'Year': 1955,
#   'Rank': 245,
#   'Company': 'Eastern Gas & Fuel Associates',
#   'Revenue (in millions)': 124.6,
#   'Profit (in millions)': '2.8'},
#  {'Year': 1955,
#   'Rank': 246,
#   'Company': 'Champion International',
#   'Revenue (in millions)': 124.1,
#   'Profit (in millions)': '4.7'},
#  {'Year': 1955,
#   'Rank': 247,
#   'Company': 'Pittsburgh Steel',
#   'Revenue (in millions)': 124.0,
#   'Profit (in millions)': '2.2'},
#  {'Year': 1955,
#   'Rank': 248,
#   'Company': 'Tecumseh Products',
#   'Revenue (in millions)': 124.0,
#   'Profit (in millions)': '5.7'},
#  {'Year': 1955,
#   'Rank': 249,
#   'Company': 'Kelsey-Hayes',
#   'Revenue (in millions)': 123.8,
#   'Profit (in millions)': '5.5'},
#  {'Year': 1955,
#   'Rank': 250,
#   'Company': 'General Precision Equipment',
#   'Revenue (in millions)': 123.3,
#   'Profit (in millions)': '5.5'},
#  {'Year': 1955,
#   'Rank': 251,
#   'Company': 'BOC',
#   'Revenue (in millions)': 123.3,
#   'Profit (in millions)': '6.3'},
#  {'Year': 1955,
#   'Rank': 252,
#   'Company': 'McDonnell Douglas',
#   'Revenue (in millions)': 123.1,
#   'Profit (in millions)': '3.6'},
#  {'Year': 1955,
#   'Rank': 253,
#   'Company': 'Eli Lilly',
#   'Revenue (in millions)': 122.3,
#   'Profit (in millions)': '11.3'},
#  {'Year': 1955,
#   'Rank': 254,
#   'Company': 'General Host',
#   'Revenue (in millions)': 122.1,
#   'Profit (in millions)': '2.2'},
#  {'Year': 1955,
#   'Rank': 255,
#   'Company': 'Stokely-Van Camp',
#   'Revenue (in millions)': 121.7,
#   'Profit (in millions)': '3'},
#  {'Year': 1955,
#   'Rank': 256,
#   'Company': 'Westinghouse Air Brake',
#   'Revenue (in millions)': 121.5,
#   'Profit (in millions)': '7.8'},
#  {'Year': 1955,
#   'Rank': 257,
#   'Company': 'American-Marietta',
#   'Revenue (in millions)': 120.7,
#   'Profit (in millions)': '5.5'},
#  {'Year': 1955,
#   'Rank': 258,
#   'Company': 'Mack Trucks',
#   'Revenue (in millions)': 120.3,
#   'Profit (in millions)': '1.3'},
#  {'Year': 1955,
#   'Rank': 259,
#   'Company': 'Sunshine Biscuits',
#   'Revenue (in millions)': 119.2,
#   'Profit (in millions)': '6'},
#  {'Year': 1955,
#   'Rank': 260,
#   'Company': 'Marathon',
#   'Revenue (in millions)': 117.8,
#   'Profit (in millions)': '7.5'},
#  {'Year': 1955,
#   'Rank': 261,
#   'Company': 'Keebler',
#   'Revenue (in millions)': 117.2,
#   'Profit (in millions)': '1.9'},
#  {'Year': 1955,
#   'Rank': 262,
#   'Company': 'Gair (Robert)',
#   'Revenue (in millions)': 116.4,
#   'Profit (in millions)': '5.1'},
#  {'Year': 1955,
#   'Rank': 263,
#   'Company': 'Bemis',
#   'Revenue (in millions)': 115.8,
#   'Profit (in millions)': '1.3'},
#  {'Year': 1955,
#   'Rank': 264,
#   'Company': 'Seeger Refrigerator',
#   'Revenue (in millions)': 112.6,
#   'Profit (in millions)': '6'},
#  {'Year': 1955,
#   'Rank': 265,
#   'Company': 'Murray Corp.',
#   'Revenue (in millions)': 112.5,
#   'Profit (in millions)': '5.8'},
#  {'Year': 1955,
#   'Rank': 266,
#   'Company': 'Warren Petroleum',
#   'Revenue (in millions)': 112.4,
#   'Profit (in millions)': '8.9'},
#  {'Year': 1955,
#   'Rank': 267,
#   'Company': 'Mead',
#   'Revenue (in millions)': 111.8,
#   'Profit (in millions)': '5.8'},
#  {'Year': 1955,
#   'Rank': 268,
#   'Company': 'Crown Holdings',
#   'Revenue (in millions)': 111.4,
#   'Profit (in millions)': '1.4'},
#  {'Year': 1955,
#   'Rank': 269,
#   'Company': 'Link-Belt',
#   'Revenue (in millions)': 111.2,
#   'Profit (in millions)': '5.4'},
#  {'Year': 1955,
#   'Rank': 270,
#   'Company': 'Scovill',
#   'Revenue (in millions)': 111.0,
#   'Profit (in millions)': '4.4'},
#  {'Year': 1955,
#   'Rank': 271,
#   'Company': 'Cincinnati Milacron',
#   'Revenue (in millions)': 110.5,
#   'Profit (in millions)': '9.3'},
#  {'Year': 1955,
#   'Rank': 272,
#   'Company': 'Parke, Davis',
#   'Revenue (in millions)': 109.9,
#   'Profit (in millions)': '10.5'},
#  {'Year': 1955,
#   'Rank': 273,
#   'Company': 'Abex',
#   'Revenue (in millions)': 109.9,
#   'Profit (in millions)': '4.3'},
#  {'Year': 1955,
#   'Rank': 274,
#   'Company': 'Budd',
#   'Revenue (in millions)': 109.5,
#   'Profit (in millions)': '9.6'},
#  {'Year': 1955,
#   'Rank': 275,
#   'Company': 'Anaconda Wire & Cable',
#   'Revenue (in millions)': 108.7,
#   'Profit (in millions)': '4.7'},
#  {'Year': 1955,
#   'Rank': 276,
#   'Company': 'Fairbanks, Morse',
#   'Revenue (in millions)': 108.0,
#   'Profit (in millions)': '2.5'},
#  {'Year': 1955,
#   'Rank': 277,
#   'Company': 'CVS',
#   'Revenue (in millions)': 107.9,
#   'Profit (in millions)': '6'},
#  {'Year': 1955,
#   'Rank': 278,
#   'Company': 'Allied Mills',
#   'Revenue (in millions)': 106.7,
#   'Profit (in millions)': '3.2'},
#  {'Year': 1955,
#   'Rank': 279,
#   'Company': 'Bridgeport Brass',
#   'Revenue (in millions)': 106.0,
#   'Profit (in millions)': '5.1'},
#  {'Year': 1955,
#   'Rank': 280,
#   'Company': 'Spencer Kellogg & Sons',
#   'Revenue (in millions)': 105.7,
#   'Profit (in millions)': '2.6'},
#  {'Year': 1955,
#   'Rank': 281,
#   'Company': 'Union Camp',
#   'Revenue (in millions)': 105.5,
#   'Profit (in millions)': '10.8'},
#  {'Year': 1955,
#   'Rank': 282,
#   'Company': 'GAF',
#   'Revenue (in millions)': 105.0,
#   'Profit (in millions)': '2.5'},
#  {'Year': 1955,
#   'Rank': 283,
#   'Company': 'Fairmont Foods',
#   'Revenue (in millions)': 104.6,
#   'Profit (in millions)': '0.8'},
#  {'Year': 1955,
#   'Rank': 284,
#   'Company': 'WestPoint Stevens',
#   'Revenue (in millions)': 104.5,
#   'Profit (in millions)': '4.1'},
#  {'Year': 1955,
#   'Rank': 285,
#   'Company': 'Colorado Milling & Elevator',
#   'Revenue (in millions)': 104.1,
#   'Profit (in millions)': '1.1'},
#  {'Year': 1955,
#   'Rank': 286,
#   'Company': 'Anchor Hocking',
#   'Revenue (in millions)': 103.7,
#   'Profit (in millions)': '5.5'},
#  {'Year': 1955,
#   'Rank': 287,
#   'Company': 'Rohr',
#   'Revenue (in millions)': 101.6,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1955,
#   'Rank': 288,
#   'Company': 'Garrett',
#   'Revenue (in millions)': 101.2,
#   'Profit (in millions)': '2.8'},
#  {'Year': 1955,
#   'Rank': 289,
#   'Company': 'Blaw-Knox',
#   'Revenue (in millions)': 101.1,
#   'Profit (in millions)': '4.1'},
#  {'Year': 1955,
#   'Rank': 290,
#   'Company': 'Diamond International',
#   'Revenue (in millions)': 100.8,
#   'Profit (in millions)': '5.6'},
#  {'Year': 1955,
#   'Rank': 292,
#   'Company': 'Textron',
#   'Revenue (in millions)': 99.7,
#   'Profit (in millions)': '1.3'},
#  {'Year': 1955,
#   'Rank': 293,
#   'Company': 'Lion Oil',
#   'Revenue (in millions)': 98.6,
#   'Profit (in millions)': '11.1'},
#  {'Year': 1955,
#   'Rank': 294,
#   'Company': 'Sharon Steel',
#   'Revenue (in millions)': 98.2,
#   'Profit (in millions)': '3.1'},
#  {'Year': 1955,
#   'Rank': 296,
#   'Company': 'GK Technologies',
#   'Revenue (in millions)': 97.4,
#   'Profit (in millions)': '5.2'},
#  {'Year': 1955,
#   'Rank': 298,
#   'Company': 'Ward Foods',
#   'Revenue (in millions)': 95.2,
#   'Profit (in millions)': '1.5'},
#  {'Year': 1955,
#   'Rank': 299,
#   'Company': 'St. Joseph Lead',
#   'Revenue (in millions)': 95.0,
#   'Profit (in millions)': '7.5'},
#  {'Year': 1955,
#   'Rank': 300,
#   'Company': 'Flintkote',
#   'Revenue (in millions)': 94.8,
#   'Profit (in millions)': '5.1'},
#  {'Year': 1955,
#   'Rank': 301,
#   'Company': 'Interstate Brands',
#   'Revenue (in millions)': 94.2,
#   'Profit (in millions)': '3.2'},
#  {'Year': 1955,
#   'Rank': 302,
#   'Company': 'Imcera Group',
#   'Revenue (in millions)': 93.6,
#   'Profit (in millions)': '6'},
#  {'Year': 1955,
#   'Rank': 303,
#   'Company': 'Maxus Energy',
#   'Revenue (in millions)': 93.5,
#   'Profit (in millions)': '5.5'},
#  {'Year': 1955,
#   'Rank': 304,
#   'Company': 'Chemetron',
#   'Revenue (in millions)': 93.4,
#   'Profit (in millions)': '5.2'},
#  {'Year': 1955,
#   'Rank': 305,
#   'Company': 'York International',
#   'Revenue (in millions)': 93.3,
#   'Profit (in millions)': '2.9'},
#  {'Year': 1955,
#   'Rank': 306,
#   'Company': 'Kendall',
#   'Revenue (in millions)': 93.2,
#   'Profit (in millions)': '4.2'},
#  {'Year': 1955,
#   'Rank': 307,
#   'Company': 'Squibb',
#   'Revenue (in millions)': 93.0,
#   'Profit (in millions)': '3.4'},
#  {'Year': 1955,
#   'Rank': 308,
#   'Company': 'Stewart-Warner',
#   'Revenue (in millions)': 92.9,
#   'Profit (in millions)': '2.8'},
#  {'Year': 1955,
#   'Rank': 309,
#   'Company': 'Case',
#   'Revenue (in millions)': 92.4,
#   'Profit (in millions)': '-0.5'},
#  {'Year': 1955,
#   'Rank': 310,
#   'Company': 'Ex-Cell-O',
#   'Revenue (in millions)': 92.3,
#   'Profit (in millions)': '8.8'},
#  {'Year': 1955,
#   'Rank': 311,
#   'Company': 'Du Mont (Allen B.) Labs.',
#   'Revenue (in millions)': 91.9,
#   'Profit (in millions)': '0.9'},
#  {'Year': 1955,
#   'Rank': 312,
#   'Company': 'U.S. Pipe & Foundry',
#   'Revenue (in millions)': 91.5,
#   'Profit (in millions)': '9'},
#  {'Year': 1955,
#   'Rank': 313,
#   'Company': 'Fibreboard',
#   'Revenue (in millions)': 91.5,
#   'Profit (in millions)': '5.5'},
#  {'Year': 1955,
#   'Rank': 314,
#   'Company': 'Clark Equipment',
#   'Revenue (in millions)': 91.1,
#   'Profit (in millions)': '5.7'},
#  {'Year': 1955,
#   'Rank': 315,
#   'Company': 'Plymouth Oil',
#   'Revenue (in millions)': 90.9,
#   'Profit (in millions)': '6.8'},
#  {'Year': 1955,
#   'Rank': 316,
#   'Company': 'Collins Radio',
#   'Revenue (in millions)': 90.3,
#   'Profit (in millions)': '3.4'},
#  {'Year': 1955,
#   'Rank': 317,
#   'Company': 'Sunbeam/Oster',
#   'Revenue (in millions)': 90.1,
#   'Profit (in millions)': '6.9'},
#  {'Year': 1955,
#   'Rank': 318,
#   'Company': 'Inmont',
#   'Revenue (in millions)': 89.8,
#   'Profit (in millions)': '3.3'},
#  {'Year': 1955,
#   'Rank': 319,
#   'Company': 'Amsted Industries',
#   'Revenue (in millions)': 89.0,
#   'Profit (in millions)': '3.6'},
#  {'Year': 1955,
#   'Rank': 320,
#   'Company': 'Abbott Laboratories',
#   'Revenue (in millions)': 88.1,
#   'Profit (in millions)': '8.7'},
#  {'Year': 1955,
#   'Rank': 321,
#   'Company': 'Yale & Towne Manufacturing',
#   'Revenue (in millions)': 87.9,
#   'Profit (in millions)': '1.8'},
#  {'Year': 1955,
#   'Rank': 322,
#   'Company': 'Servel',
#   'Revenue (in millions)': 87.8,
#   'Profit (in millions)': '-8.2'},
#  {'Year': 1955,
#   'Rank': 323,
#   'Company': 'Long-Bell Lumber Co.',
#   'Revenue (in millions)': 87.7,
#   'Profit (in millions)': '3.7'},
#  {'Year': 1955,
#   'Rank': 324,
#   'Company': 'Motor Products',
#   'Revenue (in millions)': 87.0,
#   'Profit (in millions)': '-1.1'},
#  {'Year': 1955,
#   'Rank': 325,
#   'Company': 'ITT Rayonier',
#   'Revenue (in millions)': 86.9,
#   'Profit (in millions)': '11.9'},
#  {'Year': 1955,
#   'Rank': 326,
#   'Company': 'Best Foods',
#   'Revenue (in millions)': 86.9,
#   'Profit (in millions)': '5.6'},
#  {'Year': 1955,
#   'Rank': 327,
#   'Company': 'Gaylord Container',
#   'Revenue (in millions)': 86.5,
#   'Profit (in millions)': '7'},
#  {'Year': 1955,
#   'Rank': 328,
#   'Company': 'Virginia-Carolina Chemical',
#   'Revenue (in millions)': 85.4,
#   'Profit (in millions)': '3.6'},
#  {'Year': 1955,
#   'Rank': 329,
#   'Company': 'Beaunit',
#   'Revenue (in millions)': 85.3,
#   'Profit (in millions)': '4.5'},
#  {'Year': 1955,
#   'Rank': 330,
#   'Company': 'Pepperell Manufacturing',
#   'Revenue (in millions)': 85.3,
#   'Profit (in millions)': '2.4'},
#  {'Year': 1955,
#   'Rank': 331,
#   'Company': 'Amerada Hess',
#   'Revenue (in millions)': 85.0,
#   'Profit (in millions)': '19.8'},
#  {'Year': 1955,
#   'Rank': 332,
#   'Company': 'Texasgulf',
#   'Revenue (in millions)': 84.6,
#   'Profit (in millions)': '30.5'},
#  {'Year': 1955,
#   'Rank': 333,
#   'Company': 'Lone Star Industries',
#   'Revenue (in millions)': 84.4,
#   'Profit (in millions)': '12.6'},
#  {'Year': 1955,
#   'Rank': 334,
#   'Company': 'Royal McBee',
#   'Revenue (in millions)': 84.4,
#   'Profit (in millions)': '2.8'},
#  {'Year': 1955,
#   'Rank': 335,
#   'Company': 'Eagle-Picher Industries',
#   'Revenue (in millions)': 83.2,
#   'Profit (in millions)': '2.4'},
#  {'Year': 1955,
#   'Rank': 336,
#   'Company': 'Wm. Wrigley Jr.',
#   'Revenue (in millions)': 82.6,
#   'Profit (in millions)': '11.4'},
#  {'Year': 1955,
#   'Rank': 337,
#   'Company': 'Stauffer Chemical',
#   'Revenue (in millions)': 82.6,
#   'Profit (in millions)': '5.7'},
#  {'Year': 1955,
#   'Rank': 338,
#   'Company': 'Wagner Electric',
#   'Revenue (in millions)': 82.2,
#   'Profit (in millions)': '1.9'},
#  {'Year': 1955,
#   'Rank': 339,
#   'Company': 'Marshall-Wells',
#   'Revenue (in millions)': 81.9,
#   'Profit (in millions)': '1.5'},
#  {'Year': 1955,
#   'Rank': 340,
#   'Company': 'Dan River',
#   'Revenue (in millions)': 81.8,
#   'Profit (in millions)': '2.8'},
#  {'Year': 1955,
#   'Rank': 341,
#   'Company': 'Keystone Consolidated Industries',
#   'Revenue (in millions)': 81.1,
#   'Profit (in millions)': '5.7'},
#  {'Year': 1955,
#   'Rank': 342,
#   'Company': 'Maytag',
#   'Revenue (in millions)': 81.1,
#   'Profit (in millions)': '6.7'},
#  {'Year': 1955,
#   'Rank': 343,
#   'Company': 'City Products',
#   'Revenue (in millions)': 80.8,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1955,
#   'Rank': 344,
#   'Company': 'Thomas J. Lipton',
#   'Revenue (in millions)': 80.8,
#   'Profit (in millions)': '3.1'},
#  {'Year': 1955,
#   'Rank': 345,
#   'Company': 'Emerson Radio & Phonograph',
#   'Revenue (in millions)': 80.6,
#   'Profit (in millions)': '1.9'},
#  {'Year': 1955,
#   'Rank': 346,
#   'Company': 'Cluett Peabody',
#   'Revenue (in millions)': 80.4,
#   'Profit (in millions)': '3'},
#  {'Year': 1955,
#   'Rank': 347,
#   'Company': 'Hazel-Atlas Glass',
#   'Revenue (in millions)': 79.2,
#   'Profit (in millions)': '3.6'},
#  {'Year': 1955,
#   'Rank': 348,
#   'Company': 'Gerber Products',
#   'Revenue (in millions)': 78.9,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1955,
#   'Rank': 349,
#   'Company': 'Great Western Sugar',
#   'Revenue (in millions)': 78.5,
#   'Profit (in millions)': '4.4'},
#  {'Year': 1955,
#   'Rank': 350,
#   'Company': 'Tobin Packing',
#   'Revenue (in millions)': 78.5,
#   'Profit (in millions)': '1'},
#  {'Year': 1955,
#   'Rank': 351,
#   'Company': 'Beech Aircraft',
#   'Revenue (in millions)': 78.0,
#   'Profit (in millions)': '3.4'},
#  {'Year': 1955,
#   'Rank': 352,
#   'Company': 'ESB',
#   'Revenue (in millions)': 77.7,
#   'Profit (in millions)': '7.8'},
#  {'Year': 1955,
#   'Rank': 354,
#   'Company': 'Rockwell Manufacturing',
#   'Revenue (in millions)': 76.5,
#   'Profit (in millions)': '5.7'},
#  {'Year': 1955,
#   'Rank': 355,
#   'Company': 'Ruberoid',
#   'Revenue (in millions)': 76.4,
#   'Profit (in millions)': '4.6'},
#  {'Year': 1955,
#   'Rank': 356,
#   'Company': 'Paccar',
#   'Revenue (in millions)': 76.4,
#   'Profit (in millions)': '2.4'},
#  {'Year': 1955,
#   'Rank': 357,
#   'Company': 'Butler Manufacturing',
#   'Revenue (in millions)': 76.2,
#   'Profit (in millions)': '3.3'},
#  {'Year': 1955,
#   'Rank': 358,
#   'Company': 'Superior Oil',
#   'Revenue (in millions)': 76.1,
#   'Profit (in millions)': '10.4'},
#  {'Year': 1955,
#   'Rank': 359,
#   'Company': 'Olivetti Underwood',
#   'Revenue (in millions)': 76.0,
#   'Profit (in millions)': '1.2'},
#  {'Year': 1955,
#   'Rank': 360,
#   'Company': 'Certainteed',
#   'Revenue (in millions)': 75.8,
#   'Profit (in millions)': '5.3'},
#  {'Year': 1955,
#   'Rank': 361,
#   'Company': 'National Container',
#   'Revenue (in millions)': 75.6,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1955,
#   'Rank': 362,
#   'Company': 'Lukens Steel',
#   'Revenue (in millions)': 75.0,
#   'Profit (in millions)': '2'},
#  {'Year': 1955,
#   'Rank': 363,
#   'Company': 'American Bosch Arma',
#   'Revenue (in millions)': 74.4,
#   'Profit (in millions)': '2.6'},
#  {'Year': 1955,
#   'Rank': 364,
#   'Company': 'PepsiCo',
#   'Revenue (in millions)': 74.2,
#   'Profit (in millions)': '6.2'},
#  {'Year': 1955,
#   'Rank': 365,
#   'Company': 'Stanley Works',
#   'Revenue (in millions)': 73.8,
#   'Profit (in millions)': '3.9'},
#  {'Year': 1955,
#   'Rank': 366,
#   'Company': 'New York Shipbuilding',
#   'Revenue (in millions)': 73.8,
#   'Profit (in millions)': '2.4'},
#  {'Year': 1955,
#   'Rank': 367,
#   'Company': 'Glen Alden',
#   'Revenue (in millions)': 73.5,
#   'Profit (in millions)': '0.2'},
#  {'Year': 1955,
#   'Rank': 368,
#   'Company': 'Outboard Marine',
#   'Revenue (in millions)': 73.4,
#   'Profit (in millions)': '5.5'},
#  {'Year': 1955,
#   'Rank': 369,
#   'Company': 'Hines (Edward) Lumber',
#   'Revenue (in millions)': 73.3,
#   'Profit (in millions)': '3.7'},
#  {'Year': 1955,
#   'Rank': 370,
#   'Company': 'Shoe Corp. of America',
#   'Revenue (in millions)': 73.2,
#   'Profit (in millions)': '2.3'},
#  {'Year': 1955,
#   'Rank': 371,
#   'Company': 'Standard Coil Products',
#   'Revenue (in millions)': 72.9,
#   'Profit (in millions)': '2.9'},
#  {'Year': 1955,
#   'Rank': 372,
#   'Company': 'Norris-Thermador',
#   'Revenue (in millions)': 72.6,
#   'Profit (in millions)': '2.9'},
#  {'Year': 1955,
#   'Rank': 373,
#   'Company': 'American Chain & Cable',
#   'Revenue (in millions)': 72.2,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1955,
#   'Rank': 374,
#   'Company': 'Carborundum',
#   'Revenue (in millions)': 71.9,
#   'Profit (in millions)': '3.3'},
#  {'Year': 1955,
#   'Rank': 375,
#   'Company': 'Interlake',
#   'Revenue (in millions)': 71.8,
#   'Profit (in millions)': '3.7'},
#  {'Year': 1955,
#   'Rank': 376,
#   'Company': 'Riegel Textile',
#   'Revenue (in millions)': 71.0,
#   'Profit (in millions)': '1.3'},
#  {'Year': 1955,
#   'Rank': 377,
#   'Company': 'Todd Shipyards',
#   'Revenue (in millions)': 70.4,
# ...
#   'Profit (in millions)': '2.6'},
#  {'Year': 1956,
#   'Rank': 387,
#   'Company': 'McGraw-Hill',
#   'Revenue (in millions)': 76.7,
#   'Profit (in millions)': '6.3'},
#  {'Year': 1956,
#   'Rank': 388,
#   'Company': 'Bulova Watch',
#   'Revenue (in millions)': 76.4,
#   'Profit (in millions)': '3'},
#  {'Year': 1956,
#   'Rank': 389,
#   'Company': 'Kroehler Manufacturing',
#   'Revenue (in millions)': 76.2,
#   'Profit (in millions)': '4.1'},
#  {'Year': 1956,
#   'Rank': 390,
#   'Company': 'Bristol-Myers Squibb',
#   'Revenue (in millions)': 75.7,
#   'Profit (in millions)': '4.9'},
#  {'Year': 1956,
#   'Rank': 391,
#   'Company': 'Barium Steel',
#   'Revenue (in millions)': 75.1,
#   'Profit (in millions)': '0.7'},
#  {'Year': 1956,
#   'Rank': 392,
#   'Company': 'Hartmarx',
#   'Revenue (in millions)': 74.8,
#   'Profit (in millions)': '1.7'},
#  {'Year': 1956,
#   'Rank': 393,
#   'Company': 'Mansfield Tire & Rubber',
#   'Revenue (in millions)': 74.6,
#   'Profit (in millions)': '1.8'},
#  {'Year': 1956,
#   'Rank': 394,
#   'Company': 'Cerro',
#   'Revenue (in millions)': 74.1,
#   'Profit (in millions)': '14'},
#  {'Year': 1956,
#   'Rank': 395,
#   'Company': 'Daystrom',
#   'Revenue (in millions)': 73.8,
#   'Profit (in millions)': '1.7'},
#  {'Year': 1956,
#   'Rank': 396,
#   'Company': 'American Bosch Arma',
#   'Revenue (in millions)': 73.8,
#   'Profit (in millions)': '3.4'},
#  {'Year': 1956,
#   'Rank': 397,
#   'Company': 'Mohasco',
#   'Revenue (in millions)': 73.7,
#   'Profit (in millions)': '1.7'},
#  {'Year': 1956,
#   'Rank': 398,
#   'Company': 'Joslyn Manufacturing & Supply',
#   'Revenue (in millions)': 73.5,
#   'Profit (in millions)': '3.2'},
#  {'Year': 1956,
#   'Rank': 399,
#   'Company': 'AM International',
#   'Revenue (in millions)': 73.4,
#   'Profit (in millions)': '6.7'},
#  {'Year': 1956,
#   'Rank': 400,
#   'Company': 'Minnesota & Ontario Paper',
#   'Revenue (in millions)': 73.1,
#   'Profit (in millions)': '7.4'},
#  {'Year': 1956,
#   'Rank': 401,
#   'Company': 'I-T-E Imperial',
#   'Revenue (in millions)': 73.0,
#   'Profit (in millions)': '1.8'},
#  {'Year': 1956,
#   'Rank': 402,
#   'Company': 'Murray Corp.',
#   'Revenue (in millions)': 72.9,
#   'Profit (in millions)': '5.7'},
#  {'Year': 1956,
#   'Rank': 403,
#   'Company': 'Bibb Manufacturing',
#   'Revenue (in millions)': 72.8,
#   'Profit (in millions)': '1.9'},
#  {'Year': 1956,
#   'Rank': 404,
#   'Company': 'Great Western Sugar',
#   'Revenue (in millions)': 72.7,
#   'Profit (in millions)': '4.2'},
#  {'Year': 1956,
#   'Rank': 405,
#   'Company': 'Richardson-Vicks',
#   'Revenue (in millions)': 72.7,
#   'Profit (in millions)': '6.5'},
#  {'Year': 1956,
#   'Rank': 406,
#   'Company': 'Minneapolis-Moline',
#   'Revenue (in millions)': 72.3,
#   'Profit (in millions)': '0.7'},
#  {'Year': 1956,
#   'Rank': 407,
#   'Company': 'Clevite',
#   'Revenue (in millions)': 71.9,
#   'Profit (in millions)': '4.9'},
#  {'Year': 1956,
#   'Rank': 408,
#   'Company': 'Bucyrus-Erie',
#   'Revenue (in millions)': 71.7,
#   'Profit (in millions)': '6.5'},
#  {'Year': 1956,
#   'Rank': 409,
#   'Company': 'Lees (James) & Sons',
#   'Revenue (in millions)': 71.3,
#   'Profit (in millions)': '3.4'},
#  {'Year': 1956,
#   'Rank': 410,
#   'Company': 'American Forest Products',
#   'Revenue (in millions)': 71.3,
#   'Profit (in millions)': '2.6'},
#  {'Year': 1956,
#   'Rank': 411,
#   'Company': 'American Enka',
#   'Revenue (in millions)': 71.3,
#   'Profit (in millions)': '7.1'},
#  {'Year': 1956,
#   'Rank': 412,
#   'Company': 'Celotex',
#   'Revenue (in millions)': 71.1,
#   'Profit (in millions)': '5.1'},
#  {'Year': 1956,
#   'Rank': 413,
#   'Company': 'American Optical',
#   'Revenue (in millions)': 71.0,
#   'Profit (in millions)': '2.6'},
#  {'Year': 1956,
#   'Rank': 414,
#   'Company': 'Crowell-Collier Publishing',
#   'Revenue (in millions)': 70.9,
#   'Profit (in millions)': '0.8'},
#  {'Year': 1956,
#   'Rank': 415,
#   'Company': 'Lehigh Portland Cement',
#   'Revenue (in millions)': 70.9,
#   'Profit (in millions)': '11.3'},
#  {'Year': 1956,
#   'Rank': 416,
#   'Company': 'National Can',
#   'Revenue (in millions)': 70.9,
#   'Profit (in millions)': '1'},
#  {'Year': 1956,
#   'Rank': 417,
#   'Company': 'Times Mirror',
#   'Revenue (in millions)': 70.7,
#   'Profit (in millions)': '3.2'},
#  {'Year': 1956,
#   'Rank': 418,
#   'Company': 'Ideal Basic Industries',
#   'Revenue (in millions)': 70.0,
#   'Profit (in millions)': '13.8'},
#  {'Year': 1956,
#   'Rank': 419,
#   'Company': 'Dayco',
#   'Revenue (in millions)': 69.2,
#   'Profit (in millions)': '2.3'},
#  {'Year': 1956,
#   'Rank': 420,
#   'Company': 'Remington Arms',
#   'Revenue (in millions)': 69.0,
#   'Profit (in millions)': '7.9'},
#  {'Year': 1956,
#   'Rank': 421,
#   'Company': 'Armstrong Rubber',
#   'Revenue (in millions)': 69.0,
#   'Profit (in millions)': '2.7'},
#  {'Year': 1956,
#   'Rank': 422,
#   'Company': 'Avon Products',
#   'Revenue (in millions)': 68.9,
#   'Profit (in millions)': '6'},
#  {'Year': 1956,
#   'Rank': 423,
#   'Company': 'American Agricultural Chemical',
#   'Revenue (in millions)': 68.7,
#   'Profit (in millions)': '4.4'},
#  {'Year': 1956,
#   'Rank': 424,
#   'Company': 'Carey (Philip) Manufacturing',
#   'Revenue (in millions)': 68.0,
#   'Profit (in millions)': '2.6'},
#  {'Year': 1956,
#   'Rank': 425,
#   'Company': 'Pennwalt Corp',
#   'Revenue (in millions)': 67.8,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1956,
#   'Rank': 426,
#   'Company': 'Mueller Brass',
#   'Revenue (in millions)': 67.7,
#   'Profit (in millions)': '2.5'},
#  {'Year': 1956,
#   'Rank': 427,
#   'Company': 'Arvin Industries',
#   'Revenue (in millions)': 67.4,
#   'Profit (in millions)': '4.1'},
#  {'Year': 1956,
#   'Rank': 428,
#   'Company': 'Cuban Atlantic Sugar',
#   'Revenue (in millions)': 67.3,
#   'Profit (in millions)': '3.1'},
#  {'Year': 1956,
#   'Rank': 429,
#   'Company': 'Tennessee Corp.',
#   'Revenue (in millions)': 66.5,
#   'Profit (in millions)': '7.7'},
#  {'Year': 1956,
#   'Rank': 430,
#   'Company': 'Joy Global',
#   'Revenue (in millions)': 66.3,
#   'Profit (in millions)': '1.5'},
#  {'Year': 1956,
#   'Rank': 431,
#   'Company': 'Berkshire Hathaway',
#   'Revenue (in millions)': 65.5,
#   'Profit (in millions)': '0.3'},
#  {'Year': 1956,
#   'Rank': 432,
#   'Company': 'Savannah Sugar Refining',
#   'Revenue (in millions)': 64.6,
#   'Profit (in millions)': '1.8'},
#  {'Year': 1956,
#   'Rank': 433,
#   'Company': 'Ekco Products',
#   'Revenue (in millions)': 64.5,
#   'Profit (in millions)': '5.2'},
#  {'Year': 1956,
#   'Rank': 434,
#   'Company': 'Calumet & Hecia',
#   'Revenue (in millions)': 64.4,
#   'Profit (in millions)': '3.6'},
#  {'Year': 1956,
#   'Rank': 435,
#   'Company': 'Ceco Industries',
#   'Revenue (in millions)': 64.3,
#   'Profit (in millions)': '2.5'},
#  {'Year': 1956,
#   'Rank': 436,
#   'Company': 'International Silver',
#   'Revenue (in millions)': 64.2,
#   'Profit (in millions)': '3.1'},
#  {'Year': 1956,
#   'Rank': 437,
#   'Company': 'Todd Shipyards',
#   'Revenue (in millions)': 64.2,
#   'Profit (in millions)': '1.1'},
#  {'Year': 1956,
#   'Rank': 438,
#   'Company': 'Robertshaw Controls',
#   'Revenue (in millions)': 64.0,
#   'Profit (in millions)': '3.8'},
#  {'Year': 1956,
#   'Rank': 439,
#   'Company': 'P.R. Mallory',
#   'Revenue (in millions)': 63.9,
#   'Profit (in millions)': '2.2'},
#  {'Year': 1956,
#   'Rank': 440,
#   'Company': 'Solar Aircraft',
#   'Revenue (in millions)': 63.9,
#   'Profit (in millions)': '2.1'},
#  {'Year': 1956,
#   'Rank': 441,
#   'Company': 'American Metal Products',
#   'Revenue (in millions)': 63.5,
#   'Profit (in millions)': '4.3'},
#  {'Year': 1956,
#   'Rank': 442,
#   'Company': 'Chicago Pneumatic Tool',
#   'Revenue (in millions)': 63.4,
#   'Profit (in millions)': '7.4'},
#  {'Year': 1956,
#   'Rank': 443,
#   'Company': 'Freeport Sulphur',
#   'Revenue (in millions)': 63.3,
#   'Profit (in millions)': '12.4'},
#  {'Year': 1956,
#   'Rank': 444,
#   'Company': 'Lily-Tulip Cup',
#   'Revenue (in millions)': 63.1,
#   'Profit (in millions)': '5.3'},
#  {'Year': 1956,
#   'Rank': 445,
#   'Company': 'Columbian Carbon',
#   'Revenue (in millions)': 62.8,
#   'Profit (in millions)': '6.3'},
#  {'Year': 1956,
#   'Rank': 446,
#   'Company': 'Bliss (E.W.)',
#   'Revenue (in millions)': 62.8,
#   'Profit (in millions)': '2.1'},
#  {'Year': 1956,
#   'Rank': 447,
#   'Company': 'National Homes',
#   'Revenue (in millions)': 62.3,
#   'Profit (in millions)': '2.1'},
#  {'Year': 1956,
#   'Rank': 448,
#   'Company': 'Suntide Refining',
#   'Revenue (in millions)': 62.1,
#   'Profit (in millions)': '1.6'},
#  {'Year': 1956,
#   'Rank': 449,
#   'Company': 'Bird & Son',
#   'Revenue (in millions)': 61.7,
#   'Profit (in millions)': '2.4'},
#  {'Year': 1956,
#   'Rank': 450,
#   'Company': 'Cutler-Hammer',
#   'Revenue (in millions)': 61.6,
#   'Profit (in millions)': '5.6'},
#  {'Year': 1956,
#   'Rank': 451,
#   'Company': 'Publicker Industries',
#   'Revenue (in millions)': 61.5,
#   'Profit (in millions)': '-1.8'},
#  {'Year': 1956,
#   'Rank': 452,
#   'Company': 'Canada Dry',
#   'Revenue (in millions)': 61.4,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1956,
#   'Rank': 453,
#   'Company': 'Consolidated Papers',
#   'Revenue (in millions)': 61.2,
#   'Profit (in millions)': '5.6'},
#  {'Year': 1956,
#   'Rank': 454,
#   'Company': 'Climax Molybdenum',
#   'Revenue (in millions)': 61.1,
#   'Profit (in millions)': '17.4'},
#  {'Year': 1956,
#   'Rank': 455,
#   'Company': 'Anderson-Prichard Oil',
#   'Revenue (in millions)': 61.0,
#   'Profit (in millions)': '5'},
#  {'Year': 1956,
#   'Rank': 456,
#   'Company': 'Harshaw Chemical',
#   'Revenue (in millions)': 60.9,
#   'Profit (in millions)': '2.5'},
#  {'Year': 1956,
#   'Rank': 457,
#   'Company': 'Butler Manufacturing',
#   'Revenue (in millions)': 60.8,
#   'Profit (in millions)': '1.7'},
#  {'Year': 1956,
#   'Rank': 458,
#   'Company': 'Bates Manufacturing',
#   'Revenue (in millions)': 60.7,
#   'Profit (in millions)': '2.1'},
#  {'Year': 1956,
#   'Rank': 459,
#   'Company': 'Standard Coil Products',
#   'Revenue (in millions)': 60.5,
#   'Profit (in millions)': '-0.3'},
#  {'Year': 1956,
#   'Rank': 460,
#   'Company': 'Consolidated Coppermines',
#   'Revenue (in millions)': 60.5,
#   'Profit (in millions)': '6.2'},
#  {'Year': 1956,
#   'Rank': 461,
#   'Company': 'Continental Foundry & Machine',
#   'Revenue (in millions)': 60.4,
#   'Profit (in millions)': '2.9'},
#  {'Year': 1956,
#   'Rank': 462,
#   'Company': 'Atlas Powder',
#   'Revenue (in millions)': 60.3,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1956,
#   'Rank': 463,
#   'Company': 'Elgin National Watch',
#   'Revenue (in millions)': 60.1,
#   'Profit (in millions)': '1.6'},
#  {'Year': 1956,
#   'Rank': 464,
#   'Company': 'Erwin Mills',
#   'Revenue (in millions)': 59.9,
#   'Profit (in millions)': '0.7'},
#  {'Year': 1956,
#   'Rank': 465,
#   'Company': 'Mullins Manufacturing',
#   'Revenue (in millions)': 59.8,
#   'Profit (in millions)': '1.7'},
#  {'Year': 1956,
#   'Rank': 466,
#   'Company': 'Congoleum',
#   'Revenue (in millions)': 59.8,
#   'Profit (in millions)': '2.2'},
#  {'Year': 1956,
#   'Rank': 467,
#   'Company': 'Gould-National Batteries',
#   'Revenue (in millions)': 59.7,
#   'Profit (in millions)': '2.6'},
#  {'Year': 1956,
#   'Rank': 468,
#   'Company': 'Tobin Packing',
#   'Revenue (in millions)': 59.3,
#   'Profit (in millions)': '1.1'},
#  {'Year': 1956,
#   'Rank': 469,
#   'Company': 'Premcor',
#   'Revenue (in millions)': 59.0,
#   'Profit (in millions)': '1.4'},
#  {'Year': 1956,
#   'Rank': 470,
#   'Company': 'Natl. Malleable & Steel Castings',
#   'Revenue (in millions)': 59.0,
#   'Profit (in millions)': '2.4'},
#  {'Year': 1956,
#   'Rank': 471,
#   'Company': 'Crown Central',
#   'Revenue (in millions)': 58.8,
#   'Profit (in millions)': '1.7'},
#  {'Year': 1956,
#   'Rank': 472,
#   'Company': 'Dole',
#   'Revenue (in millions)': 58.8,
#   'Profit (in millions)': '1.4'},
#  {'Year': 1956,
#   'Rank': 473,
#   'Company': 'Glen Alden',
#   'Revenue (in millions)': 58.7,
#   'Profit (in millions)': '0.2'},
#  {'Year': 1956,
#   'Rank': 474,
#   'Company': 'Servel',
#   'Revenue (in millions)': 58.6,
#   'Profit (in millions)': '-4'},
#  {'Year': 1956,
#   'Rank': 475,
#   'Company': 'Stanley Home Products',
#   'Revenue (in millions)': 58.5,
#   'Profit (in millions)': '3.1'},
#  {'Year': 1956,
#   'Rank': 476,
#   'Company': 'Alan Wood Steel',
#   'Revenue (in millions)': 58.4,
#   'Profit (in millions)': '2.6'},
#  {'Year': 1956,
#   'Rank': 477,
#   'Company': 'Laclede Steel',
#   'Revenue (in millions)': 58.2,
#   'Profit (in millions)': '4'},
#  {'Year': 1956,
#   'Rank': 478,
#   'Company': 'Briggs & Stratton',
#   'Revenue (in millions)': 58.1,
#   'Profit (in millions)': '6.6'},
#  {'Year': 1956,
#   'Rank': 479,
#   'Company': 'Du Mont (Allen B.) Labs.',
#   'Revenue (in millions)': 57.8,
#   'Profit (in millions)': '-3.7'},
#  {'Year': 1956,
#   'Rank': 480,
#   'Company': 'Visking',
#   'Revenue (in millions)': 57.7,
#   'Profit (in millions)': '5.1'},
#  {'Year': 1956,
#   'Rank': 481,
#   'Company': 'Vertol Aircraft',
#   'Revenue (in millions)': 57.7,
#   'Profit (in millions)': '1.6'},
#  {'Year': 1956,
#   'Rank': 482,
#   'Company': 'Bohn Aluminum & Brass',
#   'Revenue (in millions)': 57.5,
#   'Profit (in millions)': '2.2'},
#  {'Year': 1956,
#   'Rank': 483,
#   'Company': 'Vanadium',
#   'Revenue (in millions)': 57.3,
#   'Profit (in millions)': '5.4'},
#  {'Year': 1956,
#   'Rank': 484,
#   'Company': 'Sutherland Paper',
#   'Revenue (in millions)': 57.3,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1956,
#   'Rank': 485,
#   'Company': 'Blue Bell',
#   'Revenue (in millions)': 57.1,
#   'Profit (in millions)': '1.8'},
#  {'Year': 1956,
#   'Rank': 486,
#   'Company': 'Graniteville Co.',
#   'Revenue (in millions)': 56.8,
#   'Profit (in millions)': '1.3'},
#  {'Year': 1956,
#   'Rank': 487,
#   'Company': 'Commercial Solvents',
#   'Revenue (in millions)': 56.6,
#   'Profit (in millions)': '3.5'},
#  {'Year': 1956,
#   'Rank': 488,
#   'Company': 'Pittsburgh Coke & Chemical',
#   'Revenue (in millions)': 56.6,
#   'Profit (in millions)': '3.1'},
#  {'Year': 1956,
#   'Rank': 489,
#   'Company': 'General Refractories',
#   'Revenue (in millions)': 56.5,
#   'Profit (in millions)': '6'},
#  {'Year': 1956,
#   'Rank': 490,
#   'Company': 'Oxford Paper',
#   'Revenue (in millions)': 56.4,
#   'Profit (in millions)': '4.1'},
#  {'Year': 1956,
#   'Rank': 491,
#   'Company': 'Langendorf United Bakeries',
#   'Revenue (in millions)': 56.4,
#   'Profit (in millions)': '1.3'},
#  {'Year': 1956,
#   'Rank': 492,
#   'Company': 'South Penn Oil',
#   'Revenue (in millions)': 55.8,
#   'Profit (in millions)': '6.1'},
#  {'Year': 1956,
#   'Rank': 493,
#   'Company': 'Signal Oil Gas',
#   'Revenue (in millions)': 55.7,
#   'Profit (in millions)': '9.6'},
#  {'Year': 1956,
#   'Rank': 494,
#   'Company': 'Champlin Oil & Refining',
#   'Revenue (in millions)': 55.7,
#   'Profit (in millions)': '7'},
#  {'Year': 1956,
#   'Rank': 495,
#   'Company': 'Great Northern Paper',
#   'Revenue (in millions)': 55.7,
#   'Profit (in millions)': '5'},
#  {'Year': 1956,
#   'Rank': 496,
#   'Company': 'Sheller Manufacturing',
#   'Revenue (in millions)': 55.6,
#   'Profit (in millions)': '3.8'},
#  {'Year': 1956,
#   'Rank': 497,
#   'Company': 'Holly Sugar',
#   'Revenue (in millions)': 55.5,
#   'Profit (in millions)': '2.2'},
#  {'Year': 1956,
#   'Rank': 498,
#   'Company': 'Consolidated Cigar',
#   'Revenue (in millions)': 55.3,
#   'Profit (in millions)': '2.2'},
#  {'Year': 1956,
#   'Rank': 499,
#   'Company': 'Weatherhead',
#   'Revenue (in millions)': 55.2,
#   'Profit (in millions)': '2.3'},
#  {'Year': 1956,
#   'Rank': 500,
#   'Company': 'Warren (S.D.)',
#   'Revenue (in millions)': 55.1,
#   'Profit (in millions)': '2.9'},
#  {'Year': 1957,
#   'Rank': 1,
#   'Company': 'General Motors',
#   'Revenue (in millions)': 10796.4,
#   'Profit (in millions)': '847.4'},
#  {'Year': 1957,
#   'Rank': 2,
#   'Company': 'Exxon Mobil',
#   'Revenue (in millions)': 7126.9,
#   'Profit (in millions)': '808.5'},
#  {'Year': 1957,
#   'Rank': 3,
#   'Company': 'Ford Motor',
#   'Revenue (in millions)': 4647.0,
#   'Profit (in millions)': '236.6'},
#  {'Year': 1957,
#   'Rank': 4,
#   'Company': 'U.S. Steel',
#   'Revenue (in millions)': 4228.9,
#   'Profit (in millions)': '348.1'},
#  {'Year': 1957,
#   'Rank': 5,
#   'Company': 'General Electric',
#   'Revenue (in millions)': 4090.0,
#   'Profit (in millions)': '213.8'},
#  {'Year': 1957,
#   'Rank': 6,
#   'Company': 'Mobil',
#   'Revenue (in millions)': 2750.3,
#   'Profit (in millions)': '249.5'},
#  {'Year': 1957,
#   'Rank': 7,
#   'Company': 'Chrysler',
#   'Revenue (in millions)': 2676.3,
#   'Profit (in millions)': '20'},
#  {'Year': 1957,
#   'Rank': 8,
#   'Company': 'Esmark',
#   'Revenue (in millions)': 2429.3,
#   'Profit (in millions)': '14'},
#  ...]

# %%
json_arr.sort(key=lambda x: x["Profit (in millions)"], reverse = True)
print(json_arr[:20])
# Out:
# [{'Year': 2004, 'Rank': 46, 'Company': 'Microsoft', 'Revenue (in millions)': 32187.0, 'Profit (in millions)': '9993'}, {'Year': 1999, 'Rank': 315, 'Company': 'Gannett', 'Revenue (in millions)': 5121.3, 'Profit (in millions)': '999.9'}, {'Year': 1999, 'Rank': 238, 'Company': 'KeyCorp', 'Revenue (in millions)': 7100.0, 'Profit (in millions)': '996'}, {'Year': 2001, 'Rank': 222, 'Company': 'St. Paul Travelers Cos.', 'Revenue (in millions)': 8607.6, 'Profit (in millions)': '993.5'}, {'Year': 1997, 'Rank': 228, 'Company': 'PNC Financial Services', 'Revenue (in millions)': 6333.8, 'Profit (in millions)': '992.2'}, {'Year': 1969, 'Rank': 54, 'Company': 'International Paper', 'Revenue (in millions)': 1561.8, 'Profit (in millions)': '99.9'}, {'Year': 2002, 'Rank': 222, 'Company': 'SCI Systems', 'Revenue (in millions)': 8713.9, 'Profit (in millions)': '99.9'}, {'Year': 2003, 'Rank': 318, 'Company': 'Barnes & Noble', 'Revenue (in millions)': 5269.3, 'Profit (in millions)': '99.9'}, {'Year': 1980, 'Rank': 149, 'Company': 'Nabisco Brands', 'Revenue (in millions)': 2362.0, 'Profit (in millions)': '99.8'}, {'Year': 1991, 'Rank': 249, 'Company': 'National Service Industries', 'Revenue (in millions)': 1647.8, 'Profit (in millions)': '99.7'}, {'Year': 1994, 'Rank': 346, 'Company': 'Applied Materials', 'Revenue (in millions)': 1080.0, 'Profit (in millions)': '99.7'}, {'Year': 1977, 'Rank': 85, 'Company': 'General Dynamics', 'Revenue (in millions)': 2553.5, 'Profit (in millions)': '99.6'}, {'Year': 1979, 'Rank': 141, 'Company': 'Whirlpool', 'Revenue (in millions)': 2082.9, 'Profit (in millions)': '99.6'}, {'Year': 1985, 'Rank': 133, 'Company': 'Combustion Engineering', 'Revenue (in millions)': 3057.5, 'Profit (in millions)': '99.6'}, {'Year': 1997, 'Rank': 440, 'Company': 'Oxford Health Plans', 'Revenue (in millions)': 3075.0, 'Profit (in millions)': '99.6'}, {'Year': 2003, 'Rank': 500, 'Company': 'Neiman Marcus', 'Revenue (in millions)': 2948.3, 'Profit (in millions)': '99.6'}, {'Year': 1975, 'Rank': 80, 'Company': 'Burlington Industries Equity', 'Revenue (in millions)': 2330.0, 'Profit (in millions)': '99.5'}, {'Year': 1976, 'Rank': 55, 'Company': 'Ralston Purina', 'Revenue (in millions)': 3149.1, 'Profit (in millions)': '99.5'}, {'Year': 2003, 'Rank': 282, 'Company': 'Interpublic Group', 'Revenue (in millions)': 6203.6, 'Profit (in millions)': '99.5'}, {'Year': 1976, 'Rank': 44, 'Company': 'General Foods', 'Revenue (in millions)': 3675.1, 'Profit (in millions)': '99.4'}]
